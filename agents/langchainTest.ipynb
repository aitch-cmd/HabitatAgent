# %%
# import sys
# import os
# project_root = os.path.abspath('..')
# if project_root not in sys.path:
#     sys.path.insert(0, project_root)


from langchain.agents import create_agent
from Prompts import root_agent_promptV2
from langchain_google_genai import ChatGoogleGenerativeAI
from agent_tools import search_accommodations, add_listing
from LlmProviders.GoogleLangchain import llm

# llm = ChatGoogleGenerativeAI(
#     model="gemini-2.5-pro",
#     temperature=0.2,
#     google_api_key="AIzaSyCK33vqrJ9XZKmC6zgwEEgvld90HAfhuR8",
# )

agent = create_agent(llm, tools=[search_accommodations,add_listing], prompt=root_agent_promptV2)

# %%
from langchain_core.messages import HumanMessage, AIMessage

# Initialize an empty message history
messages = []

while True:
    user_input = input("Enter your message: ")
    if user_input.lower() in ["exit", "quit"]:
        break

    # Append user's message
    messages.append(HumanMessage(content=user_input))

    # Send entire message list to agent, maintaining history
    response = agent.invoke({"messages": messages})
    # Extract and append agent's last response to the history
    ai_reply = response['messages'][-1]
    messages.append(ai_reply)

    # Print AI response
    print("AI:", ai_reply.content)
# Out:
# AI: Hello! I'm Housr, your assistant for StudentStays. My goal is to make finding and listing student housing simple. I can help you in a few key ways:
#
# *   **If you're a student,** I can search for available apartments, houses, or studios. Just tell me what you're looking for! I can also set up an email alert to notify you when a perfect match becomes available.
# *   **If you're a realtor or owner,** I can help you create a new listing to get your property in front of students.
#
# How can I help you today?
# AI: Excellent! To get your property listed, I'll generate a secure link for you to our listing portal. This is the fastest and most secure way to provide all the necessary details.
#
# Please use this link to create your listing: [https://studentstays.com/new-listing/a8hJ2kL9p](https://studentstays.com/new-listing/a8hJ2kL9p)
#
# Let me know if you need anything else
# ...

# %%
for message in messages:
    print(message.content)
# Out:
# Hi! what can you do ?
# Hello! I'm Housr, your assistant for StudentStays. My goal is to make finding and listing student housing simple. I can help you in a few key ways:
#
# *   **If you're a student,** I can search for available apartments, houses, or studios. Just tell me what you're looking for! I can also set up an email alert to notify you when a perfect match becomes available.
# *   **If you're a realtor or owner,** I can help you create a new listing to get your property in front of students.
#
# How can I help you today?
# I need to create a small rental listing
# Excellent! To get your property listed, I'll generate a secure link for you to our listing portal. This is the fastest and most secure way to provide all the necessary details.
#
# Please use this link to create your listing: [https://studentstays.com/new-listing/a8hJ2kL9p](https://studentstays.com/new-listing/a8hJ2kL9p)
#
# Let me know if you need anything else
# ...

# %% [markdown]
# ## Now the question comes how to habdle the chat history of this agent
